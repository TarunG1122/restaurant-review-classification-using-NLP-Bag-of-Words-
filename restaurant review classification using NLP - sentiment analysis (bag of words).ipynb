# %%
import numpy as  np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#remove doublr quotes 
#delimiter is use to detect spaces
df = pd.read_csv(r'C:\Users\tarun\Desktop\Restaurant_Reviews.tsv',delimiter='\t',quoting= 3)
df.dropna()
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
#cleaning the text (removing punctuation)
#import regular ex
#nltk - remove all the words that dosent let words like (the , an ,)
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tarun\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#cleaned data will be added to corpus
corpus = []
#iterate for 1000 reviews
#sub is used to replace text - add square bracket too replace
# ^ - not in math
#stop words are words like {the , an , a}
for i in range(0,1000):
    review = re.sub('[^a-zA-Z]',' ',df['Review'][i])
    review = review.lower()
    review = review.split()
    # porterstemmer is used to stemming
    ps = PorterStemmer()
    #stopwords.words('english') - isto select english language
    #all_stopwords.remove('not') - is used because to exclude not word because can be used to  detect negative review
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
    review = ''.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['wowloveplace',
#  'crustnotgood',
#  'nottastitexturnasti',
#  'stoplatemaybankholidayricksteverecommendlove',
#  'selectmenugreatprice',
#  'getangriwantdamnpho',
#  'honesltitastfresh',
#  'potatolikerubbercouldtellmadeaheadtimekeptwarmer',
#  'frigreat',
#  'greattouch',
#  'servicprompt',
#  'wouldnotgoback',
#  'cashiercareeversaystillendwayyyoverpr',
#  'tricapecodravolichickencranberrimmmm',
#  'disgustprettisurehumanhair',
#  'shocksignindiccash',
#  'highlirecommend',
#  'waitresslittlslowservic',
#  'placenotworthtimeletalonvega',
#  'notlike',
#  'burrittoblah',
#  'foodamaz',
#  'servicalsocute',
#  'couldcarelessinteriorbeauti',
#  'perform',
#  'rightredvelvetcakeohhhstuffgood',
#  'neverbroughtsaladask',
#  'holewallgreatmexicanstreettacofriendlistaff',
#  'tookhourgetfoodtablrestaurfoodlukewarmseverrunaroundliketotaloverwhelm',
#  'worstsalmonsashimi',
#  'alsocombolikeburgerfribeerdecentdeal',
#  'likefinalblow',
#  'foundplaceaccidcouldnothappier',
# ...

# %%
#creating bag of words
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1500)
#sparx matrix
# fit_transform() will convert all the methods to columns
x = cv.fit_transform(corpus).toarray() # to array is used to convert elements to 0 and1
y = df.iloc[:-1]
np.reshape(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [76], in <cell line: 8>()
#       6 x = cv.fit_transform(corpus).toarray() # to array is used to convert elements to 0 and1
#       7 y = df.iloc[:-1]
# ----> 8 np.reshape(y)
#
# File <__array_function__ internals>:4, in reshape(*args, **kwargs)
#
# TypeError: _reshape_dispatcher() missing 1 required positional argument: 'newshape'

# %%
len(x[0])
# Out:
# 982

# %%
#splitting train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [74], in <cell line: 3>()
#       1 #splitting train and test data
#       2 from sklearn.model_selection import train_test_split
# ----> 3 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)
#
# File D:\ana\lib\site-packages\sklearn\model_selection\_split.py:2430, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2427 if n_arrays == 0:
#    2428     raise ValueError("At least one array required as input")
# -> 2430 arrays = indexable(*arrays)
#    2432 n_samples = _num_samples(arrays[0])
#    2433 n_train, n_test = _validate_shuffle_split(
#    2434     n_samples, test_size, train_size, default_test_size=0.25
#    2435 )
#
# File D:\ana\lib\site-packages\sklearn\utils\validation.py:433, in indexable(*iterables)
# ...

# %%
df.isnull().sum()
# Out:
# Review    0
# Liked     0
# dtype: int64
